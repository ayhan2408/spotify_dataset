# %% [markdown]
# **SPOTİFY UYGULAMASI**
#
# *burda spotify dataset inin uzerinde birkac işlem , duzeltme ve gorsellestirme uygulamalrı yaptım veri seti duzgun oldugu icin duzeltme fazla yapılmadı.*

# %%
import pandas as pd
dosya_yolu2  = r"C:\Users\reha\Downloads\spotify-2023.csv"
spotify = pd.read_csv(dosya_yolu2  ,  encoding = "cp1254")
spot = spotify.copy()
spot.head()
spot2 = spot.head(5)
#burda sırasıyla ilk once indirmis oldugum dataseti uygulamaya aktardım daha sonra kod calısmadıgı icin yazılım turunu "cp1254" e cevirdim normalde utf-8 fakat burda calısması
#daha sonrasıbda kopyasını aldım bu datasetin ve fazla bizle alakalı olmayan columns ları vardı bunu bir asagıki kod satırında sildim ve daha yararlı bilgiler elimizde kaldı
#ardından elimizde cok fazla dger oldugu icin tam anlamıyla verilere ulasamıyorduk o yuzden bir nevi orneklem aldım tam orneklem denmez ama o mantıkta ilk 5 degeri aldım .

# %%
empty_forme_columns = ["danceability_%" , "valence_%" ,	"energy_%" , "acousticness_%" , "instrumentalness_%" , "liveness_%" , "speechiness_%"]
spot.drop(empty_forme_columns , axis = 1 , inplace = True) 
#burda işte yukarıda soyledigim silme işlemini yapıyorum ve dataset i  daha anlasılır bir hale getirdim burdaki axis = 1 sutunu ifade etmek icin kullanılıyor , inplace ise kalıcı olmasını ayrladık.
spot.head(5)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  in_apple_charts  \
# ...

# %%
spot["artist(s)_name"].value_counts().head(50) #burda ilk deger olarak sıralamada en ustte bulunan 50 sanatcıyı gostermeyi sagladık
# Out:
# Taylor Swift          34
# The Weeknd            22
# Bad Bunny             19
# SZA                   19
# Harry Styles          17
# Kendrick Lamar        12
# Morgan Wallen         11
# Ed Sheeran             9
# BTS                    8
# Feid                   8
# Drake, 21 Savage       8
# Labrinth               7
# Olivia Rodrigo         7
# NewJeans               6
# Doja Cat               6
# Billie Eilish          5
# Drake                  4
# IVE                    4
# Arctic Monkeys         4
# Karol G                4
# Adele                  4
# Bruno Mars             4
# Quevedo                4
# Mï¿½ï¿½ne              4
# Eminem                 4
# Imagine Dragons        3
# Post Malone            3
# BLACKPINK              3
# Joji                   3
# Justin Bieber          3
# Jack Harlow            3
# Beyoncï¿               3
# The Neighbourhood      3
# Coldplay               3
# ENHYPEN                3
# Lewis Capaldi          3
# Lana Del Rey           3
# ...

# %%
sns.boxplot(x = "artist(s)_name" , y = "released_year" , data = spot2);
#burda ise sonradan olusturdugumuz spot2 datasetini tablo haline getirdik fazla veri oldugu takdirde tablo anlasılamaz ve yorumlanamz bir hale burundugu icin boyle kucuk bir veride bu işlem yapıldı .

# %%
spot_month = spot.head(100)
spot_month  #burda ilk bas dataset teki aylar ile ilgili bir grafik olusturabilmek icin bir kopya olustdurduk
# Out:
#                              track_name     artist(s)_name  artist_count  \
# 0   Seven (feat. Latto) (Explicit Ver.)   Latto, Jung Kook             2
# 1                                  LALA        Myke Towers             1
# 2                               vampire     Olivia Rodrigo             1
# 3                          Cruel Summer       Taylor Swift             1
# 4                        WHERE SHE GOES          Bad Bunny             1
# ..                                  ...                ...           ...
# 95          All My Life (feat. J. Cole)  J. Cole, Lil Durk             2
# 96                    Say Yes To Heaven       Lana Del Rey             1
# 97                               Snooze                SZA             1
# 98                   Summertime Sadness       Lana Del Rey             1
# 99                             Take Two                BTS             1
#
#     released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %%
sns.scatterplot(x = "released_month" , y = "released_day" , hue = "released_year" , data = spot_month); 
#burda ise x eksenine ay ları , y eksenine Gun leri koyarak ve hue parametresine yılları koyarak cunku yıl degişkeni digerlerine gore sayı olarak biraz daha az daha sonrasında grafigi olusturmus olduk.

# %%
spot_month["artist(s)_name"].value_counts()
#ilk 100 deger icindeki hangi sanatcıdan kac toplam kac sanatcı olduguna dair bilgi verdi.
# Out:
# Taylor Swift        10
# Karol G              2
# The Weeknd           2
# SZA                  2
# Miley Cyrus          2
#                     ..
# Troye Sivan          1
# Dua Lipa             1
# Morgan Wallen        1
# Tainy, Bad Bunny     1
# BTS                  1
# Name: artist(s)_name, Length: 85, dtype: int64

# %%
spot.head(6)
# Out:
#                             track_name     artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)   Latto, Jung Kook             2
# 1                                 LALA        Myke Towers             1
# 2                              vampire     Olivia Rodrigo             1
# 3                         Cruel Summer       Taylor Swift             1
# 4                       WHERE SHE GOES          Bad Bunny             1
# 5                             Sprinter  Dave, Central Cee             2
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
# ...

# %%
artist = spotify[["artist(s)_name" , "streams"]]
artist
# Out:
#          artist(s)_name    streams
# 0      Latto, Jung Kook  141381703
# 1           Myke Towers  133716286
# 2        Olivia Rodrigo  140003974
# 3          Taylor Swift  800840817
# 4             Bad Bunny  303236322
# ..                  ...        ...
# 948        Selena Gomez   91473363
# 949        Taylor Swift  121871870
# 950  Feid, Paulo Londra   73513683
# 951  Feid, Sech, Jhayco  133895612
# 952           Burna Boy   96007391
#
# [953 rows x 2 columns]

# %%
sns.scatterplot(x = "artist(s)_name" , y = "streams" , data = artist.head(5));
#burda ise ilk 5 teki sarkının sanatcı ve dinlenmlerini grafiklesştirdik daha fazlası olmuyo oldugu taktirde grafik karısıyor.
